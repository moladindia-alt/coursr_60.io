# %%
import urllib

# %%
url = 'https://data.gov.il/api/3/action/datastore_search?resource_id=5c78e9fa-c2e2-4771-93ff-7f400a12f7ba&q=jones' 
fileobj = urllib.request.urlopen(url)
print (fileobj.read())
# Out:
# b'{"help": "https://data.gov.il/api/3/action/help_show?name=datastore_search", "success": true, "result": {"include_total": true, "limit": 32000, "q": "jones", "records_format": "objects", "resource_id": "5c78e9fa-c2e2-4771-93ff-7f400a12f7ba", "total_estimation_threshold": null, "records": [], "fields": [{"id": "_id", "type": "int"}, {"id": "\\u05e1\\u05de\\u05dc_\\u05d9\\u05e9\\u05d5\\u05d1", "type": "text", "info": {"label": "", "notes": "", "type_override": "text"}}, {"id": "\\u05e9\\u05dd_\\u05d9\\u05e9\\u05d5\\u05d1", "type": "text", "info": {"label": "", "notes": "", "type_override": ""}}, {"id": "\\u05e9\\u05dd_\\u05d9\\u05e9\\u05d5\\u05d1_\\u05dc\\u05d5\\u05e2\\u05d6\\u05d9", "type": "text", "info": {"label": "", "notes": "", "type_override": ""}}, {"id": "\\u05e1\\u05de\\u05dc_\\u05e0\\u05e4\\u05d4", "type": "numeric", "info": {"label": "", "notes": "", "type_override": ""}}, {"id": "\\u05e9\\u05dd_\\u05e0\\u05e4\\u05d4", "type": "text", "info": {"label": "", "notes": "", "t
# ...
